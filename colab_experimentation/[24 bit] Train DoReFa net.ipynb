# %%
# !git clone https://github.com/bCom5/Awesome-Deep-Neural-Network-Compression.git
# %cd Awesome-Deep-Neural-Network-Compression
# Out:
# Cloning into 'Awesome-Deep-Neural-Network-Compression'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 284 (delta 50), reused 70 (delta 27), pack-reused 189
# Receiving objects: 100% (284/284), 1.66 MiB | 10.33 MiB/s, done.
# Resolving deltas: 100% (144/144), done.
# /content/Awesome-Deep-Neural-Network-Compression

# %%
# %cd DoReFa
import sys
sys.path.append('../')
# includes utils?
# Out:
# /content/Awesome-Deep-Neural-Network-Compression/DoReFa

# %%
"""
Experimental implementation of Trained Ternary Quantization
"""

import os
# os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import shutil
import time

import torch
import torch.nn as nn
import torch.optim as optim

from utils.dataset import get_dataloader, get_lmdb_imagenet
from models.quantized_resnet import resnet20_cifar, resnet20_stl
from utils.quantize import test
from utils.train import accuracy
from utils.recorder import Recorder

import argparse

# %%
def boolean_string(s):
    if s not in {'False', 'True'}:
        raise ValueError('Not a valid boolean string')
    return s == 'True'

parser = argparse.ArgumentParser(description='Approximation Training')
parser.add_argument('--model', '-m', type=str, default='ResNet20', help='Model Arch')
parser.add_argument('--dataset', '-d', type=str, default='CIFAR10', help='Dataset')
parser.add_argument('--optimizer', '-o', type=str, default='Adam', help='Optimizer Method')
parser.add_argument('--quantized', '-q', type=str, default='dorefa', help='What type of quantization used')
parser.add_argument('--bitW', '-bw', type=int, default=1, help='Number of quantization bits')
parser.add_argument('--exp_spec', '-e', type=str, default='', help='Experiment Specification')
parser.add_argument('--init_lr', '-lr', type=float, default=1e-3, help='Initial Learning rate')
parser.add_argument('--n_epoch', '-n', type=int, default=100, help='Maximum training epochs')
parser.add_argument('--batch_size', '-bs', type=int, default=128, help='Batch size')
# Out:
# _StoreAction(option_strings=['--batch_size', '-bs'], dest='batch_size', nargs=None, const=None, default=128, type=<class 'int'>, choices=None, help='Batch size', metavar=None)

# %% [markdown]
# ## Set args

# %%
bits = '24'
bits_lst = ['32', '24', '16', '8', '1']
# maybe 4

args = parser.parse_args(['-m', 'ResNet20', '-d', 'CIFAR10', '-q', 'dorefa', '-bw', bits])

# %%
# ------------------------------------------
use_cuda = torch.cuda.is_available()
model_name = args.model
dataset_name = args.dataset
quantized = args.quantized
MAX_EPOCH = args.n_epoch
optimizer_type = args.optimizer # ['SGD', 'SGD-M', 'adam']
dataset_type = 'large' if dataset_name in ['ImageNet'] else 'small'
# lr_adjust = args.lr_adjust
batch_size = args.batch_size
bitW = args.bitW
# ------------------------------------------

print(args)
#input('Take a look')
# Out:
# Namespace(batch_size=128, bitW=24, dataset='CIFAR10', exp_spec='', init_lr=0.001, model='ResNet20', n_epoch=100, optimizer='Adam', quantized='dorefa')

# %% [markdown]
# ## Run code

# %%
if dataset_name in ['CIFAR10', 'STL10']:
    num_classes = 10
    save_root = '../Results/%s-%s' % (model_name, dataset_name)
elif dataset_name == 'CIFAR100':
    num_classes = 100
    save_root = '../Results/%s-%s' % (model_name, dataset_name)
elif dataset_name == 'ImageNet':
    save_root = '../Results/%s' % model_name
else:
    raise NotImplementedError


###################
# Initial Network #
###################
if model_name == 'ResNet20':
    if dataset_name in ['CIFAR10', 'CIFAR100']:
        net = resnet20_cifar(num_classes=num_classes, bitW=bitW)
    elif dataset_name in ['STL10']:
        net = resnet20_stl(num_classes=num_classes, bitW=bitW)
    else:
        raise NotImplementedError
    pretrain_path = '%s/%s-%s-pretrain.pth' % (save_root, model_name, dataset_name)
else:
    raise NotImplementedError

# if pretrain
# net.load_state_dict(torch.load(pretrain_path), strict=False)

if use_cuda:
    net.cuda()

if optimizer_type == 'SGD-M':
    optimizer = optim.SGD(net.parameters(), lr=args.init_lr, momentum=0.9, weight_decay=5e-4)
elif optimizer_type == 'SGD':
    optimizer = optim.SGD(net.parameters(), lr=args.init_lr)
elif optimizer_type in ['adam', 'Adam']:
    optimizer = optim.Adam(net.parameters(), lr=args.init_lr)
else:
    raise NotImplementedError


################
# Load Dataset #
################
if dataset_name == 'ImageNet':
    try:
        train_loader = get_lmdb_imagenet('train', batch_size)
        test_loader = get_lmdb_imagenet('test', 100)
    except:
        train_loader = get_dataloader(dataset_name, 'train', batch_size)
        test_loader = get_dataloader(dataset_name, 'test', 100)
else:
    train_loader = get_dataloader(dataset_name, 'train', batch_size)
    test_loader = get_dataloader(dataset_name, 'test', 100)


####################
# Initial Recorder #
####################
SummaryPath = '%s/runs/%s-%s-%dbits' %(save_root, quantized, optimizer_type, bitW)
if args.exp_spec is not '':
    SummaryPath += ('-' + args.exp_spec)

print('Save to %s' %SummaryPath)

if os.path.exists(SummaryPath):
    print('Record exist, remove')
    input()
    shutil.rmtree(SummaryPath)
    os.makedirs(SummaryPath)
else:
    os.makedirs(SummaryPath)
# Out:
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized CNN with bit 24
# Initial quantized Linear with bit 24
# [2020-03-15 18:42:05.338109] Loading train-None from CIFAR10
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /home/sinno/datasets/CIFAR10/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Number of training instances used: 50000
# [DATA LOADING] Loading from CIFAR10-train-None finish. Number of images: 50000, Number of batches: 391
# [2020-03-15 18:42:11.775735] Loading test-None from CIFAR10
# Found CIFAR10 in /home/sinno/datasets/CIFAR10
# Files already downloaded and verified
# [DATA LOADING] Loading from CIFAR10-test-None finish. Number of images: 10000, Number of batches: 100
# Save to ../Results/ResNet20-CIFAR10/runs/dorefa-Adam-24bits

# %%
recorder = Recorder(SummaryPath=SummaryPath, dataset_name=dataset_name)

for epoch in range(MAX_EPOCH):

    if recorder.stop:
        break

    net.train()
    end = time.time()

    recorder.reset_performance()

    print('Epoch: %d, lr: %e' %(epoch, optimizer.param_groups[0]['lr']))

    for batch_idx, (inputs, targets) in enumerate(train_loader):

        if use_cuda:
            inputs, targets = inputs.cuda(), targets.cuda()

        optimizer.zero_grad()

        outputs = net(inputs, quantized=quantized)
        losses = nn.CrossEntropyLoss()(outputs, targets)
        losses.backward()

        optimizer.step()

        recorder.update(loss=losses.item(), acc=accuracy(outputs.data, targets.data, (1, 5)),
                        batch_size=outputs.shape[0], cur_lr=optimizer.param_groups[0]['lr'], end=end)

        recorder.print_training_result(batch_idx, len(train_loader))
        end = time.time()

    test_acc = test(net, quantized_type=quantized, test_loader=test_loader, dataset_name=dataset_name)

    recorder.update(loss=None, acc=test_acc, batch_size=0, end=None, is_train=False)
    # Adjust lr
    recorder.adjust_lr(optimizer=optimizer)

print('Best test acc: %s' %recorder.get_best_test_acc())
recorder.close()
# Out:
# Epoch: 0, lr: 1.000000e-03
#  [==============>] | Loss: 1.681, Acc: 40.072% |  391/391
#  [==============>] | Test Acc: 47.880% 100/100
# Best test acc
# Current smallest training loss: 657.347
# Epoch: 1, lr: 1.000000e-03
#  [==============>] | Loss: 1.214, Acc: 56.618% |  391/391
#  [==============>] | Test Acc: 60.970% 100/100
# Best test acc
# Current smallest training loss: 474.545
# Epoch: 2, lr: 1.000000e-03
#  [==============>] | Loss: 0.987, Acc: 64.704% |  391/391
#  [==============>] | Test Acc: 64.250% 100/100
# Best test acc
# Current smallest training loss: 386.015
# Epoch: 3, lr: 1.000000e-03
#  [==============>] | Loss: 0.847, Acc: 69.900% |  391/391
#  [==============>] | Test Acc: 70.610% 100/100
# Best test acc
# Current smallest training loss: 331.230
# Epoch: 4, lr: 1.000000e-03
#  [==============>] | Loss: 0.755, Acc: 73.376% |  391/391
#  [==============>] | Test Acc: 73.200% 100/100
# Best test acc
# Current smallest training loss: 295.378
# Epoch: 5, lr: 1.000000e-03
#  [==============>] | Loss: 0.681, Acc: 76.406% |  391/391
#  [==============>] | Test Acc: 75.060% 100/100
# Best test acc
# Current smallest training loss: 266.349
# Epoch: 6, lr: 1.000000e-03
#  [==============>] | Loss: 0.634, Acc: 77.762% |  391/391
#  [==============>] | Test Acc: 76.780% 100/100
# Best test acc
# Current smallest training loss: 247.818
# Epoch: 7, lr: 1.000000e-03
#  [==============>] | Loss: 0.593, Acc: 79.290% |  391/391
#  [==============>] | Test Acc: 78.830% 100/100
# Best test acc
# Current smallest training loss: 231.717
# Epoch: 8, lr: 1.000000e-03
#  [==============>] | Loss: 0.558, Acc: 80.540% |  391/391
#  [==============>] | Test Acc: 76.050% 100/100
# Current smallest training loss: 218.194
# Epoch: 9, lr: 1.000000e-03
#  [==============>] | Loss: 0.528, Acc: 81.726% |  391/391
#  [==============>] | Test Acc: 77.990% 100/100
# Current smallest training loss: 206.490
# Epoch: 10, lr: 1.000000e-03
#  [==============>] | Loss: 0.497, Acc: 82.762% |  391/391
#  [==============>] | Test Acc: 81.620% 100/100
# Best test acc
# Current smallest training loss: 194.351
# Epoch: 11, lr: 1.000000e-03
#  [==============>] | Loss: 0.482, Acc: 83.210% |  391/391
#  [==============>] | Test Acc: 79.160% 100/100
# Current smallest training loss: 188.298
# Epoch: 12, lr: 1.000000e-03
#  [==============>] | Loss: 0.460, Acc: 84.052% |  391/391
#  [==============>] | Test Acc: 82.310% 100/100
# Best test acc
# Current smallest training loss: 179.995
# Epoch: 13, lr: 1.000000e-03
#  [==============>] | Loss: 0.435, Acc: 85.030% |  391/391
#  [==============>] | Test Acc: 82.870% 100/100
# Best test acc
# Current smallest training loss: 169.897
# Epoch: 14, lr: 1.000000e-03
#  [==============>] | Loss: 0.419, Acc: 85.524% |  391/391
#  [==============>] | Test Acc: 81.980% 100/100
# Current smallest training loss: 164.002
# Epoch: 15, lr: 1.000000e-03
#  [==============>] | Loss: 0.403, Acc: 85.952% |  391/391
#  [==============>] | Test Acc: 77.870% 100/100
# Current smallest training loss: 157.440
# Epoch: 16, lr: 1.000000e-03
#  [==============>] | Loss: 0.387, Acc: 86.614% |  391/391
#  [==============>] | Test Acc: 80.600% 100/100
# Current smallest training loss: 151.149
# Epoch: 17, lr: 1.000000e-03
#  [==============>] | Loss: 0.373, Acc: 87.060% |  391/391
#  [==============>] | Test Acc: 83.150% 100/100
# Best test acc
# Current smallest training loss: 145.676
# Epoch: 18, lr: 1.000000e-03
#  [==============>] | Loss: 0.363, Acc: 87.290% |  391/391
#  [==============>] | Test Acc: 83.740% 100/100
# Best test acc
# Current smallest training loss: 141.837
# Epoch: 19, lr: 1.000000e-03
#  [==============>] | Loss: 0.349, Acc: 87.746% |  391/391
#  [==============>] | Test Acc: 83.180% 100/100
# Current smallest training loss: 136.629
# Epoch: 20, lr: 1.000000e-03
#  [==============>] | Loss: 0.338, Acc: 88.184% |  391/391
#  [==============>] | Test Acc: 83.780% 100/100
# Best test acc
# Current smallest training loss: 132.286
# Epoch: 21, lr: 1.000000e-03
#  [==============>] | Loss: 0.330, Acc: 88.544% |  391/391
#  [==============>] | Test Acc: 84.750% 100/100
# Best test acc
# Current smallest training loss: 128.955
# Epoch: 22, lr: 1.000000e-03
#  [==============>] | Loss: 0.318, Acc: 88.984% |  391/391
#  [==============>] | Test Acc: 84.500% 100/100
# Current smallest training loss: 124.423
# Epoch: 23, lr: 1.000000e-03
#  [==============>] | Loss: 0.309, Acc: 89.222% |  391/391
#  [==============>] | Test Acc: 83.560% 100/100
# Current smallest training loss: 120.922
# Epoch: 24, lr: 1.000000e-03
#  [==============>] | Loss: 0.300, Acc: 89.558% |  391/391
#  [==============>] | Test Acc: 86.400% 100/100
# Best test acc
# Current smallest training loss: 117.193
# Epoch: 25, lr: 1.000000e-03
#  [==============>] | Loss: 0.292, Acc: 89.790% |  391/391
#  [==============>] | Test Acc: 84.990% 100/100
# Current smallest training loss: 114.113
# Epoch: 26, lr: 1.000000e-03
#  [==============>] | Loss: 0.284, Acc: 90.322% |  391/391
#  [==============>] | Test Acc: 85.840% 100/100
# Current smallest training loss: 110.877
# Epoch: 27, lr: 1.000000e-03
#  [==============>] | Loss: 0.278, Acc: 90.134% |  391/391
#  [==============>] | Test Acc: 86.040% 100/100
# Current smallest training loss: 108.589
# Epoch: 28, lr: 1.000000e-03
#  [==============>] | Loss: 0.268, Acc: 90.492% |  391/391
#  [==============>] | Test Acc: 85.140% 100/100
# Current smallest training loss: 104.851
# Epoch: 29, lr: 1.000000e-03
#  [==============>] | Loss: 0.262, Acc: 90.768% |  391/391
#  [==============>] | Test Acc: 85.070% 100/100
# Current smallest training loss: 102.372
# Epoch: 30, lr: 1.000000e-03
#  [==============>] | Loss: 0.253, Acc: 91.080% |  391/391
#  [==============>] | Test Acc: 85.540% 100/100
# Current smallest training loss: 99.003
# Epoch: 31, lr: 1.000000e-03
#  [==============>] | Loss: 0.245, Acc: 91.544% |  391/391
#  [==============>] | Test Acc: 84.840% 100/100
# Current smallest training loss: 95.606
# Epoch: 32, lr: 1.000000e-03
#  [==============>] | Loss: 0.242, Acc: 91.424% |  391/391
#  [==============>] | Test Acc: 85.290% 100/100
# Current smallest training loss: 94.668
# Epoch: 33, lr: 1.000000e-03
#  [==============>] | Loss: 0.238, Acc: 91.598% |  391/391
#  [==============>] | Test Acc: 86.650% 100/100
# Best test acc
# Current smallest training loss: 93.088
# Epoch: 34, lr: 1.000000e-03
#  [==============>] | Loss: 0.236, Acc: 91.684% |  391/391
#  [==============>] | Test Acc: 86.050% 100/100
# Current smallest training loss: 92.173
# Epoch: 35, lr: 1.000000e-03
#  [==============>] | Loss: 0.222, Acc: 92.052% |  391/391
#  [==============>] | Test Acc: 86.550% 100/100
# Current smallest training loss: 86.954
# Epoch: 36, lr: 1.000000e-03
#  [==============>] | Loss: 0.222, Acc: 92.164% |  391/391
#  [==============>] | Test Acc: 85.900% 100/100
# Current smallest training loss: 86.846
# Epoch: 37, lr: 1.000000e-03
#  [==============>] | Loss: 0.216, Acc: 92.482% |  391/391
#  [==============>] | Test Acc: 85.830% 100/100
# Current smallest training loss: 84.565
# Epoch: 38, lr: 1.000000e-03
#  [==============>] | Loss: 0.214, Acc: 92.444% |  391/391
#  [==============>] | Test Acc: 85.410% 100/100
# Current smallest training loss: 83.823
# Epoch: 39, lr: 1.000000e-03
#  [==============>] | Loss: 0.205, Acc: 92.630% |  391/391
#  [==============>] | Test Acc: 87.360% 100/100
# Best test acc
# Current smallest training loss: 80.274
# Epoch: 40, lr: 1.000000e-03
#  [==============>] | Loss: 0.201, Acc: 93.082% |  391/391
#  [==============>] | Test Acc: 87.240% 100/100
# Current smallest training loss: 78.404
# Epoch: 41, lr: 1.000000e-03
#  [==============>] | Loss: 0.196, Acc: 93.142% |  391/391
#  [==============>] | Test Acc: 87.100% 100/100
# Current smallest training loss: 76.773
# Epoch: 42, lr: 1.000000e-03
#  [==============>] | Loss: 0.194, Acc: 93.098% |  391/391
#  [==============>] | Test Acc: 87.040% 100/100
# Current smallest training loss: 75.845
# Epoch: 43, lr: 1.000000e-03
#  [==============>] | Loss: 0.190, Acc: 93.272% |  391/391
#  [==============>] | Test Acc: 87.140% 100/100
# Current smallest training loss: 74.351
# Epoch: 44, lr: 1.000000e-03
#  [==============>] | Loss: 0.187, Acc: 93.448% |  391/391
#  [==============>] | Test Acc: 87.700% 100/100
# Best test acc
# Current smallest training loss: 73.182
# Epoch: 45, lr: 1.000000e-03
#  [==============>] | Loss: 0.185, Acc: 93.482% |  391/391
#  [==============>] | Test Acc: 86.280% 100/100
# Current smallest training loss: 72.217
# Epoch: 46, lr: 1.000000e-03
#  [==============>] | Loss: 0.181, Acc: 93.620% |  391/391
#  [==============>] | Test Acc: 87.300% 100/100
# Current smallest training loss: 70.758
# Epoch: 47, lr: 1.000000e-03
#  [==============>] | Loss: 0.172, Acc: 93.870% |  391/391
#  [==============>] | Test Acc: 86.590% 100/100
# Current smallest training loss: 67.413
# Epoch: 48, lr: 1.000000e-03
#  [==============>] | Loss: 0.173, Acc: 93.796% |  391/391
#  [==============>] | Test Acc: 87.810% 100/100
# Best test acc
# Training loss: 67.624 [67.413], ascend count: 1
# Epoch: 49, lr: 1.000000e-03
#  [==============>] | Loss: 0.171, Acc: 94.046% |  391/391
#  [==============>] | Test Acc: 87.370% 100/100
# Current smallest training loss: 66.823
# Epoch: 50, lr: 1.000000e-03
#  [==============>] | Loss: 0.164, Acc: 94.198% |  391/391
#  [==============>] | Test Acc: 87.690% 100/100
# Current smallest training loss: 64.010
# Epoch: 51, lr: 1.000000e-03
#  [==============>] | Loss: 0.164, Acc: 94.194% |  391/391
#  [==============>] | Test Acc: 87.140% 100/100
# Current smallest training loss: 63.960
# Epoch: 52, lr: 1.000000e-03
#  [==============>] | Loss: 0.162, Acc: 94.128% |  391/391
#  [==============>] | Test Acc: 86.760% 100/100
# Current smallest training loss: 63.251
# Epoch: 53, lr: 1.000000e-03
#  [==============>] | Loss: 0.158, Acc: 94.292% |  391/391
#  [==============>] | Test Acc: 87.160% 100/100
# Current smallest training loss: 61.941
# Epoch: 54, lr: 1.000000e-03
#  [==============>] | Loss: 0.154, Acc: 94.550% |  391/391
#  [==============>] | Test Acc: 87.270% 100/100
# Current smallest training loss: 60.104
# Epoch: 55, lr: 1.000000e-03
#  [==============>] | Loss: 0.156, Acc: 94.418% |  391/391
#  [==============>] | Test Acc: 86.910% 100/100
# Training loss: 60.865 [60.104], ascend count: 1
# Epoch: 56, lr: 1.000000e-03
#  [==============>] | Loss: 0.149, Acc: 94.744% |  391/391
#  [==============>] | Test Acc: 86.610% 100/100
# Current smallest training loss: 58.185
# Epoch: 57, lr: 1.000000e-03
#  [==============>] | Loss: 0.148, Acc: 94.670% |  391/391
#  [==============>] | Test Acc: 87.680% 100/100
# Current smallest training loss: 57.991
# Epoch: 58, lr: 1.000000e-03
#  [==============>] | Loss: 0.143, Acc: 94.860% |  391/391
#  [==============>] | Test Acc: 87.620% 100/100
# Current smallest training loss: 56.011
# Epoch: 59, lr: 1.000000e-03
#  [==============>] | Loss: 0.140, Acc: 95.080% |  391/391
#  [==============>] | Test Acc: 87.390% 100/100
# Current smallest training loss: 54.748
# Epoch: 60, lr: 1.000000e-03
#  [==============>] | Loss: 0.134, Acc: 95.158% |  391/391
#  [==============>] | Test Acc: 87.860% 100/100
# Best test acc
# Current smallest training loss: 52.368
# Epoch: 61, lr: 1.000000e-03
#  [==============>] | Loss: 0.140, Acc: 95.014% |  391/391
#  [==============>] | Test Acc: 88.350% 100/100
# Best test acc
# Training loss: 54.603 [52.368], ascend count: 1
# Epoch: 62, lr: 1.000000e-03
#  [==============>] | Loss: 0.133, Acc: 95.272% |  391/391
#  [==============>] | Test Acc: 87.770% 100/100
# Current smallest training loss: 52.184
# Epoch: 63, lr: 1.000000e-03
#  [==============>] | Loss: 0.131, Acc: 95.384% |  391/391
#  [==============>] | Test Acc: 87.540% 100/100
# Current smallest training loss: 51.283
# Epoch: 64, lr: 1.000000e-03
#  [==============>] | Loss: 0.127, Acc: 95.466% |  391/391
#  [==============>] | Test Acc: 86.180% 100/100
# Current smallest training loss: 49.664
# Epoch: 65, lr: 1.000000e-03
#  [==============>] | Loss: 0.129, Acc: 95.402% |  391/391
#  [==============>] | Test Acc: 88.050% 100/100
# Training loss: 50.367 [49.664], ascend count: 1
# Epoch: 66, lr: 1.000000e-03
#  [==============>] | Loss: 0.126, Acc: 95.542% |  391/391
#  [==============>] | Test Acc: 86.930% 100/100
# Current smallest training loss: 49.079
# Epoch: 67, lr: 1.000000e-03
#  [==============>] | Loss: 0.122, Acc: 95.688% |  391/391
#  [==============>] | Test Acc: 88.010% 100/100
# Current smallest training loss: 47.880
# Epoch: 68, lr: 1.000000e-03
#  [==============>] | Loss: 0.122, Acc: 95.608% |  391/391
#  [==============>] | Test Acc: 87.060% 100/100
# Current smallest training loss: 47.652
# Epoch: 69, lr: 1.000000e-03
#  [==============>] | Loss: 0.127, Acc: 95.288% |  391/391
#  [==============>] | Test Acc: 87.670% 100/100
# Training loss: 49.469 [47.652], ascend count: 1
# Epoch: 70, lr: 1.000000e-03
#  [==============>] | Loss: 0.117, Acc: 95.716% |  391/391
#  [==============>] | Test Acc: 87.520% 100/100
# Current smallest training loss: 45.638
# Epoch: 71, lr: 1.000000e-03
#  [==============>] | Loss: 0.118, Acc: 95.838% |  391/391
#  [==============>] | Test Acc: 87.860% 100/100
# Training loss: 45.969 [45.638], ascend count: 1
# Epoch: 72, lr: 1.000000e-03
#  [==============>] | Loss: 0.114, Acc: 95.790% |  391/391
#  [==============>] | Test Acc: 87.300% 100/100
# Current smallest training loss: 44.740
# Epoch: 73, lr: 1.000000e-03
#  [==============>] | Loss: 0.113, Acc: 96.000% |  391/391
#  [==============>] | Test Acc: 87.860% 100/100
# Current smallest training loss: 44.156
# Epoch: 74, lr: 1.000000e-03

# %%
'''
# model.cpu();
torch.save(net.state_dict(), 'resnet20_8bit_accuracy90_2_date20_03_14.pytorch_state')

from google.colab import drive
drive.mount('/content/gdrive')
# !mv resnet20_8bit_accuracy90_2_date20_03_14.pytorch_state /content/gdrive/My\ Drive/models/resnet20_8bit_accuracy90_2_date20_03_14.pytorch_state
'''
