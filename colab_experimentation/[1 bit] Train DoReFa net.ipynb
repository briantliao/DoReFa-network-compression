# %%
# !git clone https://github.com/bCom5/Awesome-Deep-Neural-Network-Compression.git
# %cd Awesome-Deep-Neural-Network-Compression
# Out:
# Cloning into 'Awesome-Deep-Neural-Network-Compression'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 284 (delta 50), reused 70 (delta 27), pack-reused 189
# Receiving objects: 100% (284/284), 1.66 MiB | 4.25 MiB/s, done.
# Resolving deltas: 100% (144/144), done.
# /content/Awesome-Deep-Neural-Network-Compression

# %%
# %cd DoReFa
import sys
sys.path.append('../')
# includes utils?
# Out:
# /content/Awesome-Deep-Neural-Network-Compression/DoReFa

# %%
"""
Experimental implementation of Trained Ternary Quantization
"""

import os
# os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import shutil
import time

import torch
import torch.nn as nn
import torch.optim as optim

from utils.dataset import get_dataloader, get_lmdb_imagenet
from models.quantized_resnet import resnet20_cifar, resnet20_stl
from utils.quantize import test
from utils.train import accuracy
from utils.recorder import Recorder

import argparse

# %%
def boolean_string(s):
    if s not in {'False', 'True'}:
        raise ValueError('Not a valid boolean string')
    return s == 'True'

parser = argparse.ArgumentParser(description='Approximation Training')
parser.add_argument('--model', '-m', type=str, default='ResNet20', help='Model Arch')
parser.add_argument('--dataset', '-d', type=str, default='CIFAR10', help='Dataset')
parser.add_argument('--optimizer', '-o', type=str, default='Adam', help='Optimizer Method')
parser.add_argument('--quantized', '-q', type=str, default='dorefa', help='What type of quantization used')
parser.add_argument('--bitW', '-bw', type=int, default=1, help='Number of quantization bits')
parser.add_argument('--exp_spec', '-e', type=str, default='', help='Experiment Specification')
parser.add_argument('--init_lr', '-lr', type=float, default=1e-3, help='Initial Learning rate')
parser.add_argument('--n_epoch', '-n', type=int, default=100, help='Maximum training epochs')
parser.add_argument('--batch_size', '-bs', type=int, default=128, help='Batch size')
# Out:
# _StoreAction(option_strings=['--batch_size', '-bs'], dest='batch_size', nargs=None, const=None, default=128, type=<class 'int'>, choices=None, help='Batch size', metavar=None)

# %% [markdown]
# ## Set args

# %%
bits = '1'
bits_lst = ['32', '24', '16', '8', '1']
# maybe 4

args = parser.parse_args(['-m', 'ResNet20', '-d', 'CIFAR10', '-q', 'dorefa', '-bw', bits])

# %%
# ------------------------------------------
use_cuda = torch.cuda.is_available()
model_name = args.model
dataset_name = args.dataset
quantized = args.quantized
MAX_EPOCH = args.n_epoch
optimizer_type = args.optimizer # ['SGD', 'SGD-M', 'adam']
dataset_type = 'large' if dataset_name in ['ImageNet'] else 'small'
# lr_adjust = args.lr_adjust
batch_size = args.batch_size
bitW = args.bitW
# ------------------------------------------

print(args)
#input('Take a look')
# Out:
# Namespace(batch_size=128, bitW=1, dataset='CIFAR10', exp_spec='', init_lr=0.001, model='ResNet20', n_epoch=100, optimizer='Adam', quantized='dorefa')

# %% [markdown]
# ## Run code

# %%
if dataset_name in ['CIFAR10', 'STL10']:
    num_classes = 10
    save_root = '../Results/%s-%s' % (model_name, dataset_name)
elif dataset_name == 'CIFAR100':
    num_classes = 100
    save_root = '../Results/%s-%s' % (model_name, dataset_name)
elif dataset_name == 'ImageNet':
    save_root = '../Results/%s' % model_name
else:
    raise NotImplementedError


###################
# Initial Network #
###################
if model_name == 'ResNet20':
    if dataset_name in ['CIFAR10', 'CIFAR100']:
        net = resnet20_cifar(num_classes=num_classes, bitW=bitW)
    elif dataset_name in ['STL10']:
        net = resnet20_stl(num_classes=num_classes, bitW=bitW)
    else:
        raise NotImplementedError
    pretrain_path = '%s/%s-%s-pretrain.pth' % (save_root, model_name, dataset_name)
else:
    raise NotImplementedError

# if pretrain
# net.load_state_dict(torch.load(pretrain_path), strict=False)

if use_cuda:
    net.cuda()

if optimizer_type == 'SGD-M':
    optimizer = optim.SGD(net.parameters(), lr=args.init_lr, momentum=0.9, weight_decay=5e-4)
elif optimizer_type == 'SGD':
    optimizer = optim.SGD(net.parameters(), lr=args.init_lr)
elif optimizer_type in ['adam', 'Adam']:
    optimizer = optim.Adam(net.parameters(), lr=args.init_lr)
else:
    raise NotImplementedError


################
# Load Dataset #
################
if dataset_name == 'ImageNet':
    try:
        train_loader = get_lmdb_imagenet('train', batch_size)
        test_loader = get_lmdb_imagenet('test', 100)
    except:
        train_loader = get_dataloader(dataset_name, 'train', batch_size)
        test_loader = get_dataloader(dataset_name, 'test', 100)
else:
    train_loader = get_dataloader(dataset_name, 'train', batch_size)
    test_loader = get_dataloader(dataset_name, 'test', 100)


####################
# Initial Recorder #
####################
SummaryPath = '%s/runs/%s-%s-%dbits' %(save_root, quantized, optimizer_type, bitW)
if args.exp_spec is not '':
    SummaryPath += ('-' + args.exp_spec)

print('Save to %s' %SummaryPath)

if os.path.exists(SummaryPath):
    print('Record exist, remove')
    input()
    shutil.rmtree(SummaryPath)
    os.makedirs(SummaryPath)
else:
    os.makedirs(SummaryPath)
# Out:
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized CNN with bit 1
# Initial quantized Linear with bit 1
# [2020-03-14 21:19:13.184998] Loading train-None from CIFAR10
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /home/sinno/datasets/CIFAR10/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Number of training instances used: 50000
# [DATA LOADING] Loading from CIFAR10-train-None finish. Number of images: 50000, Number of batches: 391
# [2020-03-14 21:19:19.666236] Loading test-None from CIFAR10
# Found CIFAR10 in /home/sinno/datasets/CIFAR10
# Files already downloaded and verified
# [DATA LOADING] Loading from CIFAR10-test-None finish. Number of images: 10000, Number of batches: 100
# Save to ../Results/ResNet20-CIFAR10/runs/dorefa-Adam-1bits

# %%
recorder = Recorder(SummaryPath=SummaryPath, dataset_name=dataset_name)

for epoch in range(MAX_EPOCH):

    if recorder.stop:
        break

    net.train()
    end = time.time()

    recorder.reset_performance()

    print('Epoch: %d, lr: %e' %(epoch, optimizer.param_groups[0]['lr']))

    for batch_idx, (inputs, targets) in enumerate(train_loader):

        if use_cuda:
            inputs, targets = inputs.cuda(), targets.cuda()

        optimizer.zero_grad()

        outputs = net(inputs, quantized=quantized)
        losses = nn.CrossEntropyLoss()(outputs, targets)
        losses.backward()

        optimizer.step()

        recorder.update(loss=losses.item(), acc=accuracy(outputs.data, targets.data, (1, 5)),
                        batch_size=outputs.shape[0], cur_lr=optimizer.param_groups[0]['lr'], end=end)

        recorder.print_training_result(batch_idx, len(train_loader))
        end = time.time()

    test_acc = test(net, quantized_type=quantized, test_loader=test_loader, dataset_name=dataset_name)

    recorder.update(loss=None, acc=test_acc, batch_size=0, end=None, is_train=False)
    # Adjust lr
    recorder.adjust_lr(optimizer=optimizer)

print('Best test acc: %s' %recorder.get_best_test_acc())
recorder.close()
# Out:
# Epoch: 0, lr: 1.000000e-03
#  [==============>] | Loss: 2.159, Acc: 32.054% |  391/391
#  [==============>] | Test Acc: 40.360% 100/100
# Best test acc
# Current smallest training loss: 844.242
# Epoch: 1, lr: 1.000000e-03
#  [==============>] | Loss: 1.586, Acc: 43.372% |  391/391
#  [==============>] | Test Acc: 42.500% 100/100
# Best test acc
# Current smallest training loss: 619.940
# Epoch: 2, lr: 1.000000e-03
#  [==============>] | Loss: 1.422, Acc: 49.566% |  391/391
#  [==============>] | Test Acc: 51.630% 100/100
# Best test acc
# Current smallest training loss: 556.010
# Epoch: 3, lr: 1.000000e-03
#  [==============>] | Loss: 1.275, Acc: 54.864% |  391/391
#  [==============>] | Test Acc: 49.960% 100/100
# Current smallest training loss: 498.337
# Epoch: 4, lr: 1.000000e-03
#  [==============>] | Loss: 1.176, Acc: 58.518% |  391/391
#  [==============>] | Test Acc: 54.880% 100/100
# Best test acc
# Current smallest training loss: 459.929
# Epoch: 5, lr: 1.000000e-03
#  [==============>] | Loss: 1.107, Acc: 61.210% |  391/391
#  [==============>] | Test Acc: 54.770% 100/100
# Current smallest training loss: 432.854
# Epoch: 6, lr: 1.000000e-03
#  [==============>] | Loss: 1.035, Acc: 63.890% |  391/391
#  [==============>] | Test Acc: 63.030% 100/100
# Best test acc
# Current smallest training loss: 404.509
# Epoch: 7, lr: 1.000000e-03
#  [==============>] | Loss: 0.979, Acc: 65.666% |  391/391
#  [==============>] | Test Acc: 58.920% 100/100
# Current smallest training loss: 382.866
# Epoch: 8, lr: 1.000000e-03
#  [==============>] | Loss: 0.926, Acc: 67.724% |  391/391
#  [==============>] | Test Acc: 58.930% 100/100
# Current smallest training loss: 361.981
# Epoch: 9, lr: 1.000000e-03
#  [==============>] | Loss: 0.873, Acc: 69.670% |  391/391
#  [==============>] | Test Acc: 68.870% 100/100
# Best test acc
# Current smallest training loss: 341.525
# Epoch: 10, lr: 1.000000e-03
#  [==============>] | Loss: 0.837, Acc: 70.868% |  391/391
#  [==============>] | Test Acc: 68.360% 100/100
# Current smallest training loss: 327.253
# Epoch: 11, lr: 1.000000e-03
#  [==============>] | Loss: 0.802, Acc: 72.160% |  391/391
#  [==============>] | Test Acc: 66.610% 100/100
# Current smallest training loss: 313.468
# Epoch: 12, lr: 1.000000e-03
#  [==============>] | Loss: 0.776, Acc: 73.282% |  391/391
#  [==============>] | Test Acc: 62.330% 100/100
# Current smallest training loss: 303.488
# Epoch: 13, lr: 1.000000e-03
#  [==============>] | Loss: 0.745, Acc: 74.122% |  391/391
#  [==============>] | Test Acc: 73.090% 100/100
# Best test acc
# Current smallest training loss: 291.473
# Epoch: 14, lr: 1.000000e-03
#  [==============>] | Loss: 0.713, Acc: 75.142% |  391/391
#  [==============>] | Test Acc: 74.050% 100/100
# Best test acc
# Current smallest training loss: 278.917
# Epoch: 15, lr: 1.000000e-03
#  [==============>] | Loss: 0.687, Acc: 76.066% |  391/391
#  [==============>] | Test Acc: 73.490% 100/100
# Current smallest training loss: 268.806
# Epoch: 16, lr: 1.000000e-03
#  [==============>] | Loss: 0.670, Acc: 76.842% |  391/391
#  [==============>] | Test Acc: 59.080% 100/100
# Current smallest training loss: 261.933
# Epoch: 17, lr: 1.000000e-03
#  [==============>] | Loss: 0.648, Acc: 77.616% |  391/391
#  [==============>] | Test Acc: 71.740% 100/100
# Current smallest training loss: 253.338
# Epoch: 18, lr: 1.000000e-03
#  [==============>] | Loss: 0.635, Acc: 78.038% |  391/391
#  [==============>] | Test Acc: 73.650% 100/100
# Current smallest training loss: 248.270
# Epoch: 19, lr: 1.000000e-03
#  [==============>] | Loss: 0.622, Acc: 78.336% |  391/391
#  [==============>] | Test Acc: 74.910% 100/100
# Best test acc
# Current smallest training loss: 243.334
# Epoch: 20, lr: 1.000000e-03
#  [==============>] | Loss: 0.610, Acc: 78.934% |  391/391
#  [==============>] | Test Acc: 76.950% 100/100
# Best test acc
# Current smallest training loss: 238.566
# Epoch: 21, lr: 1.000000e-03
#  [==============>] | Loss: 0.589, Acc: 79.648% |  391/391
#  [==============>] | Test Acc: 70.090% 100/100
# Current smallest training loss: 230.422
# Epoch: 22, lr: 1.000000e-03
#  [==============>] | Loss: 0.583, Acc: 79.798% |  391/391
#  [==============>] | Test Acc: 65.860% 100/100
# Current smallest training loss: 228.141
# Epoch: 23, lr: 1.000000e-03
#  [==============>] | Loss: 0.573, Acc: 80.348% |  391/391
#  [==============>] | Test Acc: 76.300% 100/100
# Current smallest training loss: 224.011
# Epoch: 24, lr: 1.000000e-03
#  [==============>] | Loss: 0.557, Acc: 80.818% |  391/391
#  [==============>] | Test Acc: 76.010% 100/100
# Current smallest training loss: 217.620
# Epoch: 25, lr: 1.000000e-03
#  [==============>] | Loss: 0.551, Acc: 80.844% |  391/391
#  [==============>] | Test Acc: 76.820% 100/100
# Current smallest training loss: 215.562
# Epoch: 26, lr: 1.000000e-03
#  [==============>] | Loss: 0.544, Acc: 81.208% |  391/391
#  [==============>] | Test Acc: 78.830% 100/100
# Best test acc
# Current smallest training loss: 212.575
# Epoch: 27, lr: 1.000000e-03
#  [==============>] | Loss: 0.527, Acc: 81.788% |  391/391
#  [==============>] | Test Acc: 79.340% 100/100
# Best test acc
# Current smallest training loss: 206.222
# Epoch: 28, lr: 1.000000e-03
#  [==============>] | Loss: 0.525, Acc: 81.934% |  391/391
#  [==============>] | Test Acc: 79.190% 100/100
# Current smallest training loss: 205.413
# Epoch: 29, lr: 1.000000e-03
#  [==============>] | Loss: 0.512, Acc: 82.306% |  391/391
#  [==============>] | Test Acc: 79.160% 100/100
# Current smallest training loss: 200.326
# Epoch: 30, lr: 1.000000e-03
#  [==============>] | Loss: 0.505, Acc: 82.736% |  391/391
#  [==============>] | Test Acc: 78.910% 100/100
# Current smallest training loss: 197.319
# Epoch: 31, lr: 1.000000e-03
#  [==============>] | Loss: 0.499, Acc: 82.778% |  391/391
#  [==============>] | Test Acc: 81.100% 100/100
# Best test acc
# Current smallest training loss: 195.268
# Epoch: 32, lr: 1.000000e-03
#  [==============>] | Loss: 0.487, Acc: 83.104% |  391/391
#  [==============>] | Test Acc: 77.400% 100/100
# Current smallest training loss: 190.581
# Epoch: 33, lr: 1.000000e-03
#  [==============>] | Loss: 0.488, Acc: 83.164% |  391/391
#  [==============>] | Test Acc: 77.510% 100/100
# Training loss: 190.782 [190.581], ascend count: 1
# Epoch: 34, lr: 1.000000e-03
#  [==============>] | Loss: 0.481, Acc: 83.312% |  391/391
#  [==============>] | Test Acc: 76.280% 100/100
# Current smallest training loss: 188.056
# Epoch: 35, lr: 1.000000e-03
#  [==============>] | Loss: 0.476, Acc: 83.528% |  391/391
#  [==============>] | Test Acc: 81.710% 100/100
# Best test acc
# Current smallest training loss: 186.156
# Epoch: 36, lr: 1.000000e-03
#  [==============>] | Loss: 0.474, Acc: 83.450% |  391/391
#  [==============>] | Test Acc: 76.120% 100/100
# Current smallest training loss: 185.199
# Epoch: 37, lr: 1.000000e-03
#  [==============>] | Loss: 0.462, Acc: 84.022% |  391/391
#  [==============>] | Test Acc: 78.280% 100/100
# Current smallest training loss: 180.777
# Epoch: 38, lr: 1.000000e-03
#  [==============>] | Loss: 0.461, Acc: 83.860% |  391/391
#  [==============>] | Test Acc: 78.370% 100/100
# Current smallest training loss: 180.292
# Epoch: 39, lr: 1.000000e-03
#  [==============>] | Loss: 0.455, Acc: 84.250% |  391/391
#  [==============>] | Test Acc: 81.120% 100/100
# Current smallest training loss: 177.787
# Epoch: 40, lr: 1.000000e-03
#  [==============>] | Loss: 0.449, Acc: 84.562% |  391/391
#  [==============>] | Test Acc: 80.440% 100/100
# Current smallest training loss: 175.458
# Epoch: 41, lr: 1.000000e-03
#  [==============>] | Loss: 0.443, Acc: 84.488% |  391/391
#  [==============>] | Test Acc: 80.650% 100/100
# Current smallest training loss: 173.322
# Epoch: 42, lr: 1.000000e-03
#  [==============>] | Loss: 0.436, Acc: 84.958% |  391/391
#  [==============>] | Test Acc: 79.230% 100/100
# Current smallest training loss: 170.368
# Epoch: 43, lr: 1.000000e-03
#  [==============>] | Loss: 0.433, Acc: 85.108% |  391/391
#  [==============>] | Test Acc: 78.060% 100/100
# Current smallest training loss: 169.283
# Epoch: 44, lr: 1.000000e-03
#  [==============>] | Loss: 0.432, Acc: 85.082% |  391/391
#  [==============>] | Test Acc: 77.000% 100/100
# Current smallest training loss: 169.045
# Epoch: 45, lr: 1.000000e-03
#  [==============>] | Loss: 0.426, Acc: 85.340% |  391/391
#  [==============>] | Test Acc: 79.370% 100/100
# Current smallest training loss: 166.552
# Epoch: 46, lr: 1.000000e-03
#  [==============>] | Loss: 0.420, Acc: 85.416% |  391/391
#  [==============>] | Test Acc: 79.170% 100/100
# Current smallest training loss: 164.350
# Epoch: 47, lr: 1.000000e-03
#  [==============>] | Loss: 0.419, Acc: 85.348% |  391/391
#  [==============>] | Test Acc: 82.380% 100/100
# Best test acc
# Current smallest training loss: 163.658
# Epoch: 48, lr: 1.000000e-03
#  [==============>] | Loss: 0.406, Acc: 85.860% |  391/391
#  [==============>] | Test Acc: 76.200% 100/100
# Current smallest training loss: 158.827
# Epoch: 49, lr: 1.000000e-03
#  [==============>] | Loss: 0.408, Acc: 85.846% |  391/391
#  [==============>] | Test Acc: 82.850% 100/100
# Best test acc
# Training loss: 159.617 [158.827], ascend count: 1
# Epoch: 50, lr: 1.000000e-03
#  [==============>] | Loss: 0.402, Acc: 85.936% |  391/391
#  [==============>] | Test Acc: 83.040% 100/100
# Best test acc
# Current smallest training loss: 157.121
# Epoch: 51, lr: 1.000000e-03
#  [==============>] | Loss: 0.392, Acc: 86.506% |  391/391
#  [==============>] | Test Acc: 84.000% 100/100
# Best test acc
# Current smallest training loss: 153.078
# Epoch: 52, lr: 1.000000e-03
#  [==============>] | Loss: 0.395, Acc: 86.376% |  391/391
#  [==============>] | Test Acc: 79.600% 100/100
# Training loss: 154.324 [153.078], ascend count: 1
# Epoch: 53, lr: 1.000000e-03
#  [==============>] | Loss: 0.391, Acc: 86.498% |  391/391
#  [==============>] | Test Acc: 80.660% 100/100
# Current smallest training loss: 152.972
# Epoch: 54, lr: 1.000000e-03
#  [==============>] | Loss: 0.390, Acc: 86.346% |  391/391
#  [==============>] | Test Acc: 82.790% 100/100
# Current smallest training loss: 152.558
# Epoch: 55, lr: 1.000000e-03
#  [==============>] | Loss: 0.386, Acc: 86.626% |  391/391
#  [==============>] | Test Acc: 81.880% 100/100
# Current smallest training loss: 150.733
# Epoch: 56, lr: 1.000000e-03
#  [==============>] | Loss: 0.386, Acc: 86.616% |  391/391
#  [==============>] | Test Acc: 82.960% 100/100
# Training loss: 150.796 [150.733], ascend count: 1
# Epoch: 57, lr: 1.000000e-03
#  [==============>] | Loss: 0.382, Acc: 86.514% |  391/391
#  [==============>] | Test Acc: 84.610% 100/100
# Best test acc
# Current smallest training loss: 149.459
# Epoch: 58, lr: 1.000000e-03
#  [==============>] | Loss: 0.378, Acc: 86.954% |  391/391
#  [==============>] | Test Acc: 82.050% 100/100
# Current smallest training loss: 147.835
# Epoch: 59, lr: 1.000000e-03
#  [==============>] | Loss: 0.371, Acc: 87.052% |  391/391
#  [==============>] | Test Acc: 81.500% 100/100
# Current smallest training loss: 145.005
# Epoch: 60, lr: 1.000000e-03
#  [==============>] | Loss: 0.366, Acc: 87.234% |  391/391
#  [==============>] | Test Acc: 81.100% 100/100
# Current smallest training loss: 143.278
# Epoch: 61, lr: 1.000000e-03
#  [==============>] | Loss: 0.373, Acc: 86.962% |  391/391
#  [==============>] | Test Acc: 81.380% 100/100
# Training loss: 145.676 [143.278], ascend count: 1
# Epoch: 62, lr: 1.000000e-03
#  [==============>] | Loss: 0.367, Acc: 87.182% |  391/391
#  [==============>] | Test Acc: 81.950% 100/100
# Training loss: 143.645 [143.278], ascend count: 2
# Epoch: 63, lr: 1.000000e-03
#  [==============>] | Loss: 0.366, Acc: 87.148% |  391/391
#  [==============>] | Test Acc: 83.830% 100/100
# Current smallest training loss: 142.943
# Epoch: 64, lr: 1.000000e-03
#  [==============>] | Loss: 0.365, Acc: 87.294% |  391/391
#  [==============>] | Test Acc: 79.430% 100/100
# Current smallest training loss: 142.704
# Epoch: 65, lr: 1.000000e-03
#  [==============>] | Loss: 0.360, Acc: 87.578% |  391/391
#  [==============>] | Test Acc: 82.650% 100/100
# Current smallest training loss: 140.599
# Epoch: 66, lr: 1.000000e-03
#  [==============>] | Loss: 0.362, Acc: 87.320% |  391/391
#  [==============>] | Test Acc: 84.320% 100/100
# Training loss: 141.455 [140.599], ascend count: 1
# Epoch: 67, lr: 1.000000e-03
#  [==============>] | Loss: 0.361, Acc: 87.466% |  391/391
#  [==============>] | Test Acc: 84.140% 100/100
# Training loss: 141.298 [140.599], ascend count: 2
# Epoch: 68, lr: 1.000000e-03
#  [==============>] | Loss: 0.356, Acc: 87.312% |  391/391
#  [==============>] | Test Acc: 82.870% 100/100
# Current smallest training loss: 139.102
# Epoch: 69, lr: 1.000000e-03
#  [==============>] | Loss: 0.355, Acc: 87.662% |  391/391
#  [==============>] | Test Acc: 79.990% 100/100
# Current smallest training loss: 138.871
# Epoch: 70, lr: 1.000000e-03
#  [==============>] | Loss: 0.355, Acc: 87.594% |  391/391
#  [==============>] | Test Acc: 76.530% 100/100
# Current smallest training loss: 138.688
# Epoch: 71, lr: 1.000000e-03
#  [==============>] | Loss: 0.346, Acc: 87.948% |  391/391
#  [==============>] | Test Acc: 82.090% 100/100
# Current smallest training loss: 135.271
# Epoch: 72, lr: 1.000000e-03
#  [==============>] | Loss: 0.345, Acc: 87.914% |  391/391
#  [==============>] | Test Acc: 81.710% 100/100
# Current smallest training loss: 135.007
# Epoch: 73, lr: 1.000000e-03
#  [==============>] | Loss: 0.342, Acc: 88.090% |  391/391
#  [==============>] | Test Acc: 84.040% 100/100
# Current smallest training loss: 133.689
# Epoch: 74, lr: 1.000000e-03
#  [==============>] | Loss: 0.344, Acc: 88.074% |  391/391
#  [==============>] | Test Acc: 82.990% 100/100
# Training loss: 134.606 [133.689], ascend count: 1
# Epoch: 75, lr: 1.000000e-03
#  [==============>] | Loss: 0.344, Acc: 87.842% |  391/391
#  [==============>] | Test Acc: 83.800% 100/100
# Training loss: 134.658 [133.689], ascend count: 2
# Epoch: 76, lr: 1.000000e-03
#  [==============>] | Loss: 0.341, Acc: 88.064% |  391/391
#  [==============>] | Test Acc: 84.640% 100/100
# Best test acc
# Current smallest training loss: 133.500
# Epoch: 77, lr: 1.000000e-03
#  [==============>] | Loss: 0.343, Acc: 88.038% |  391/391
#  [==============>] | Test Acc: 82.300% 100/100
# Training loss: 133.973 [133.500], ascend count: 1
# Epoch: 78, lr: 1.000000e-03
#  [==============>] | Loss: 0.338, Acc: 88.188% |  391/391
#  [==============>] | Test Acc: 83.180% 100/100
# Current smallest training loss: 132.042
# Epoch: 79, lr: 1.000000e-03
#  [==============>] | Loss: 0.339, Acc: 88.162% |  391/391
#  [==============>] | Test Acc: 83.610% 100/100
# Training loss: 132.355 [132.042], ascend count: 1
# Epoch: 80, lr: 1.000000e-03
#  [==============>] | Loss: 0.328, Acc: 88.438% |  391/391
#  [==============>] | Test Acc: 80.530% 100/100
# Current smallest training loss: 128.129
# Epoch: 81, lr: 1.000000e-03
#  [==============>] | Loss: 0.328, Acc: 88.466% |  391/391
#  [==============>] | Test Acc: 82.550% 100/100
# Current smallest training loss: 128.110
# Epoch: 82, lr: 1.000000e-03
#  [==============>] | Loss: 0.332, Acc: 88.186% |  391/391
#  [==============>] | Test Acc: 83.420% 100/100
# Training loss: 129.941 [128.110], ascend count: 1
# Epoch: 83, lr: 1.000000e-03
#  [==============>] | Loss: 0.330, Acc: 88.494% |  391/391
#  [==============>] | Test Acc: 83.580% 100/100
# Training loss: 128.949 [128.110], ascend count: 2
# Epoch: 84, lr: 1.000000e-03
#  [==============>] | Loss: 0.330, Acc: 88.456% |  391/391
#  [==============>] | Test Acc: 83.130% 100/100
# Training loss: 129.068 [128.110], ascend count: 3
# >>>>>>>>>> [None] Learning rate change to 1.000000e-04 <<<<<<<<<<<<<
# Epoch: 85, lr: 1.000000e-04
#  [==============>] | Loss: 0.262, Acc: 90.928% |  391/391
#  [==============>] | Test Acc: 87.630% 100/100
# Best test acc
# Current smallest training loss: 102.432
# Epoch: 86, lr: 1.000000e-04
#  [==============>] | Loss: 0.240, Acc: 91.684% |  391/391
#  [==============>] | Test Acc: 87.330% 100/100
# Current smallest training loss: 93.892
# Epoch: 87, lr: 1.000000e-04
#  [==============>] | Loss: 0.236, Acc: 91.832% |  391/391
#  [==============>] | Test Acc: 87.070% 100/100
# Current smallest training loss: 92.104
# Epoch: 88, lr: 1.000000e-04
#  [==============>] | Loss: 0.233, Acc: 91.884% |  391/391
#  [==============>] | Test Acc: 87.360% 100/100
# Current smallest training loss: 91.195
# Epoch: 89, lr: 1.000000e-04
#  [==============>] | Loss: 0.230, Acc: 91.980% |  391/391
#  [==============>] | Test Acc: 87.980% 100/100
# Best test acc
# Current smallest training loss: 89.943
# Epoch: 90, lr: 1.000000e-04
#  [==============>] | Loss: 0.231, Acc: 91.920% |  391/391
#  [==============>] | Test Acc: 87.610% 100/100
# Training loss: 90.188 [89.943], ascend count: 1
# Epoch: 91, lr: 1.000000e-04
#  [==============>] | Loss: 0.227, Acc: 91.996% |  391/391
#  [==============>] | Test Acc: 87.410% 100/100
# Current smallest training loss: 88.891
# Epoch: 92, lr: 1.000000e-04
#  [==============>] | Loss: 0.225, Acc: 92.132% |  391/391
#  [==============>] | Test Acc: 87.220% 100/100
# Current smallest training loss: 87.970
# Epoch: 93, lr: 1.000000e-04
#  [==============>] | Loss: 0.228, Acc: 92.118% |  391/391
#  [==============>] | Test Acc: 87.850% 100/100
# Training loss: 89.156 [87.970], ascend count: 1
# Epoch: 94, lr: 1.000000e-04
#  [==============>] | Loss: 0.228, Acc: 91.946% |  391/391
#  [==============>] | Test Acc: 87.780% 100/100
# Training loss: 89.021 [87.970], ascend count: 2
# Epoch: 95, lr: 1.000000e-04
#  [==============>] | Loss: 0.223, Acc: 92.170% |  391/391
#  [==============>] | Test Acc: 87.100% 100/100
# Current smallest training loss: 87.191
# Epoch: 96, lr: 1.000000e-04
#  [==============>] | Loss: 0.225, Acc: 92.080% |  391/391
#  [==============>] | Test Acc: 87.470% 100/100
# Training loss: 88.086 [87.191], ascend count: 1
# Epoch: 97, lr: 1.000000e-04
#  [==============>] | Loss: 0.224, Acc: 92.208% |  391/391
#  [==============>] | Test Acc: 87.080% 100/100
# Training loss: 87.558 [87.191], ascend count: 2
# Epoch: 98, lr: 1.000000e-04
#  [==============>] | Loss: 0.226, Acc: 92.104% |  391/391
#  [==============>] | Test Acc: 87.760% 100/100
# Training loss: 88.253 [87.191], ascend count: 3
# >>>>>>>>>> [None] Learning rate change to 1.000000e-05 <<<<<<<<<<<<<
# Epoch: 99, lr: 1.000000e-05
#  [==============>] | Loss: 0.203, Acc: 92.928% |  391/391
#  [==============>] | Test Acc: 88.100% 100/100
# Best test acc
# Current smallest training loss: 79.192
# Best test acc: 88.1

# %%
# model.cpu();
torch.save(net.state_dict(), 'resnet20_1bit_accuracy88_1_date20_03_14.pytorch_state')

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls /content/gdrive/My\ Drive/models
# Out:
# resnet_w8a32_acc71_81_date20_03_12.pytorch_state

# %%
# !mv resnet20_1bit_accuracy88_1_date20_03_14.pytorch_state /content/gdrive/My\ Drive/models/resnet20_1bit_accuracy88_1_date20_03_14.pytorch_state
